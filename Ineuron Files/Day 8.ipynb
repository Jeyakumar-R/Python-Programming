# %%
#Matplotlib

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-05-07', periods = 1000), columns = ['Values'])
df.head()
# Out:
#               Values
# 2019-05-07  1.259492
# 2019-05-08 -0.883393
# 2019-05-09 -0.735125
# 2019-05-10 -0.708270
# 2019-05-11  0.452105

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-05-07', periods = 1000))

# %%
ts
# Out:
# 2019-05-07   -0.385201
# 2019-05-08   -1.121793
# 2019-05-09   -1.386290
# 2019-05-10    1.043156
# 2019-05-11    0.116379
#                 ...
# 2022-01-26    0.679424
# 2022-01-27   -0.101717
# 2022-01-28   -0.870615
# 2022-01-29    0.812718
# 2022-01-30    0.814827
# Freq: D, Length: 1000, dtype: float64

# %%
df['Values'] = df['Values'].cumsum()

# %%
df.head()
# Out:
#               Values
# 2019-05-07  1.259492
# 2019-05-08  0.376099
# 2019-05-09 -0.359026
# 2019-05-10 -1.067296
# 2019-05-11 -0.615191

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-05-07   -0.385201
# 2019-05-08   -1.506994
# 2019-05-09   -2.893284
# 2019-05-10   -1.850127
# 2019-05-11   -1.733748
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
 iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize = (15,8), title = 'Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar',figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
data = iris.drop(['species'], axis = 1)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
data.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
data.iloc[0].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
d = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])

# %%
d.head()
# Out:
#           a         b         c         d
# 0 -0.062503 -0.492449  0.962903  0.720278
# 1 -1.363541  1.726542  0.267999  0.424871
# 2  0.081419  1.183843 -0.239987  1.147156
# 3  0.996898 -0.606232 -0.296753  0.137699
# 4  0.405055 -0.966820 -0.510663 -1.499451

# %%
d.plot.bar()
# Out:
# <AxesSubplot:>

# %%
d.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['survived'].plot(kind = 'hist', title = 'plot for survived col')
# Out:
# <AxesSubplot:title={'center':'plot for survived col'}, ylabel='Frequency'>

# %%
titanic['fare'].plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
data.diff().hist(color = 'b', alpha = 0.3, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
data.hist(color = 'b', alpha = 0.3, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
data.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
data.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
data.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 50)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
h = data.iloc[0]
h
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
h.plot.pie(figsize = (10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
data.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
k = data.head(3).T

# %%
k
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
k.plot.pie(subplots = True, figsize = (20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
k.plot.pie(subplots = True, figsize = (20,20), fontsize = 15, autopct = "%.2f")
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data, figsize = (10,10), diagonal = 'kde', color = 'b')
plt.show()

# %%
ts.plot.kde() #Kernal density estimation
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['sepal_length'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(data, 'sepal_width')
# Out:
# <AxesSubplot:>

# %%
ts.plot(label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
ts.plot(style = 'r', label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
data.plot(subplots = True, sharex = False, layout = (2,3), figsize = (18,10))
plt.tight_layout()
